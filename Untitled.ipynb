# %%
import os
import boto3

# %%
os.makedirs('data', exist_ok=False)
s3 = boto3.client('s3')
with open('wendy_cnn_frames_data.zip', 'wb') as f:
    s3.download_fileobj('da-youtube-ml', 'wendy-cnn/frames/wendy_cnn_frames_data.zip', f)

# %%
# !wget https://da-youtube-ml.s3.eu-central-1.amazonaws.com/wendy-cnn/frames/wendy_cnn_frames_data.zip
# !unzip wendy_cnn_frames_data
# !rm wendy_cnn_frames_data.zip
# Out:
# --2020-09-09 17:49:18--  https://da-youtube-ml.s3.eu-central-1.amazonaws.com/wendy-cnn/frames/wendy_cnn_frames_data.zip
# Resolving da-youtube-ml.s3.eu-central-1.amazonaws.com (da-youtube-ml.s3.eu-central-1.amazonaws.com)... 52.219.74.128
# Connecting to da-youtube-ml.s3.eu-central-1.amazonaws.com (da-youtube-ml.s3.eu-central-1.amazonaws.com)|52.219.74.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3406848357 (3,2G) [application/zip]
# Saving to: ‘wendy_cnn_frames_data.zip’
#
# wendy_cnn_frames_da 100%[===================>]   3,17G  58,3MB/s    in 58s
#
# 2020-09-09 17:50:17 (56,1 MB/s) - ‘wendy_cnn_frames_data.zip’ saved [3406848357/3406848357]
#
# Archive:  wendy_cnn_frames_data.zip
#    creating: Battle/
#   inflating: Battle/E_0055_00_02_04.jpg
#   inflating: Battle/E_0055_00_02_12.jpg
#   inflating: Battle/E_0055_00_02_20.jpg
#   inflating: Battle/E_0055_00_02_26.jpg
#   inflating: Battle/E_0055_00_02_50.jpg
# ...
